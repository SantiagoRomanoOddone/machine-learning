# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.9.2'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:-1].values
y = dataset.iloc[:, -1].values

# %%
print(X)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %%
print(y)
# Out:
# [1 0 1 ... 1 1 0]

# %% [markdown]
# ### Encoding categorical data

# %% [markdown]
# Label Encoding the "Gender" column

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:, 2] = le.fit_transform(X[:, 2])

# %%
print(X)
# Out:
# [[619 'France' 0 ... 1 1 101348.88]
#  [608 'Spain' 0 ... 0 1 112542.58]
#  [502 'France' 0 ... 1 0 113931.57]
#  ...
#  [709 'France' 0 ... 0 1 42085.58]
#  [772 'Germany' 1 ... 1 0 92888.52]
#  [792 'France' 0 ... 1 0 38190.78]]

# %% [markdown]
# One Hot Encoding the "Geography" column

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
print(X)
# Out:
# [[1.0 0.0 0.0 ... 1 1 101348.88]
#  [0.0 0.0 1.0 ... 0 1 112542.58]
#  [1.0 0.0 0.0 ... 1 0 113931.57]
#  ...
#  [1.0 0.0 0.0 ... 0 1 42085.58]
#  [0.0 1.0 0.0 ... 1 0 92888.52]
#  [1.0 0.0 0.0 ... 1 0 38190.78]]

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Part 2 - Building the ANN

# %% [markdown]
# ### Initializing the ANN

# %%
ann = tf.keras.models.Sequential()

# %% [markdown]
# ### Adding the input layer and the first hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %% [markdown]
# ### Adding the second hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %% [markdown]
# ### Adding the output layer

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the ANN

# %% [markdown]
# ### Compiling the ANN

# %%
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the ANN on the Training set

# %%
ann.fit(X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 1s 969us/step - loss: 0.5380 - accuracy: 0.7960
# Epoch 2/100
# 250/250 [==============================] - 0s 979us/step - loss: 0.4742 - accuracy: 0.7960
# Epoch 3/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4497 - accuracy: 0.7960
# Epoch 4/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4355 - accuracy: 0.7960
# Epoch 5/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4270 - accuracy: 0.7960
# Epoch 6/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4214 - accuracy: 0.7960
# Epoch 7/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4164 - accuracy: 0.8001
# Epoch 8/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4116 - accuracy: 0.8077
# Epoch 9/100
# 250/250 [==============================] - 0s 961us/step - loss: 0.4057 - accuracy: 0.8173
# Epoch 10/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3989 - accuracy: 0.8304
# Epoch 11/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3923 - accuracy: 0.8385
# Epoch 12/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3857 - accuracy: 0.8438
# Epoch 13/100
# 250/250 [==============================] - 0s 972us/step - loss: 0.3806 - accuracy: 0.8457
# Epoch 14/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3754 - accuracy: 0.8476
# Epoch 15/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3711 - accuracy: 0.8514
# Epoch 16/100
# 250/250 [==============================] - 0s 964us/step - loss: 0.3678 - accuracy: 0.8539
# Epoch 17/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3653 - accuracy: 0.8555
# Epoch 18/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3625 - accuracy: 0.8558
# Epoch 19/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3608 - accuracy: 0.8579
# Epoch 20/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3588 - accuracy: 0.8579
# Epoch 21/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3576 - accuracy: 0.8565
# Epoch 22/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3565 - accuracy: 0.8590
# Epoch 23/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3553 - accuracy: 0.8585
# Epoch 24/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3542 - accuracy: 0.8594
# Epoch 25/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3532 - accuracy: 0.8606
# Epoch 26/100
# 250/250 [==============================] - 0s 993us/step - loss: 0.3528 - accuracy: 0.8597
# Epoch 27/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3520 - accuracy: 0.8604
# Epoch 28/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3513 - accuracy: 0.8600
# Epoch 29/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8606
# Epoch 30/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3501 - accuracy: 0.8611
# Epoch 31/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8610
# Epoch 32/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3490 - accuracy: 0.8612
# Epoch 33/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3480 - accuracy: 0.8620
# Epoch 34/100
# 250/250 [==============================] - 0s 966us/step - loss: 0.3481 - accuracy: 0.8621
# Epoch 35/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3476 - accuracy: 0.8616
# Epoch 36/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3472 - accuracy: 0.8629
# Epoch 37/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3469 - accuracy: 0.8612
# Epoch 38/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3463 - accuracy: 0.8606
# Epoch 39/100
# 250/250 [==============================] - 0s 975us/step - loss: 0.3461 - accuracy: 0.8610
# Epoch 40/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3456 - accuracy: 0.8621
# Epoch 41/100
# 250/250 [==============================] - 0s 978us/step - loss: 0.3453 - accuracy: 0.8620
# Epoch 42/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3453 - accuracy: 0.8625
# Epoch 43/100
# 250/250 [==============================] - 0s 982us/step - loss: 0.3447 - accuracy: 0.8627
# Epoch 44/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3447 - accuracy: 0.8630
# Epoch 45/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3444 - accuracy: 0.8626
# Epoch 46/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3440 - accuracy: 0.8633
# Epoch 47/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3438 - accuracy: 0.8622
# Epoch 48/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3435 - accuracy: 0.8636
# Epoch 49/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3435 - accuracy: 0.8636
# Epoch 50/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3431 - accuracy: 0.8637
# Epoch 51/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3433 - accuracy: 0.8616
# Epoch 52/100
# 250/250 [==============================] - 0s 995us/step - loss: 0.3425 - accuracy: 0.8637
# Epoch 53/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3426 - accuracy: 0.8637
# Epoch 54/100
# 250/250 [==============================] - 0s 949us/step - loss: 0.3425 - accuracy: 0.8629
# Epoch 55/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3421 - accuracy: 0.8639
# Epoch 56/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3420 - accuracy: 0.8634
# Epoch 57/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3417 - accuracy: 0.8637
# Epoch 58/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3416 - accuracy: 0.8639
# Epoch 59/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3414 - accuracy: 0.8634
# Epoch 60/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3411 - accuracy: 0.8626
# Epoch 61/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3410 - accuracy: 0.8629
# Epoch 62/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3409 - accuracy: 0.8645
# Epoch 63/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3406 - accuracy: 0.8640
# Epoch 64/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3402 - accuracy: 0.8616
# Epoch 65/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3404 - accuracy: 0.8637
# Epoch 66/100
# 250/250 [==============================] - 0s 972us/step - loss: 0.3400 - accuracy: 0.8640
# Epoch 67/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3396 - accuracy: 0.8636
# Epoch 68/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3391 - accuracy: 0.8644
# Epoch 69/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3392 - accuracy: 0.8629
# Epoch 70/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3388 - accuracy: 0.8654
# Epoch 71/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3382 - accuracy: 0.8639
# Epoch 72/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3383 - accuracy: 0.8624
# Epoch 73/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3382 - accuracy: 0.8630
# Epoch 74/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3378 - accuracy: 0.8643
# Epoch 75/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3379 - accuracy: 0.8636
# Epoch 76/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3374 - accuracy: 0.8631
# Epoch 77/100
# 250/250 [==============================] - 0s 949us/step - loss: 0.3374 - accuracy: 0.8634
# Epoch 78/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3372 - accuracy: 0.8648
# Epoch 79/100
# 250/250 [==============================] - 0s 995us/step - loss: 0.3372 - accuracy: 0.8627
# Epoch 80/100
# 250/250 [==============================] - 0s 983us/step - loss: 0.3371 - accuracy: 0.8637
# Epoch 81/100
#   1/250 [..............................] - ETA: 1s - loss: 0.3593 - accuracy: 0.8438
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-85138ced34b8> in <module>
# ----> 1 ann.fit(X_train, y_train, batch_size = 32, epochs = 100)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1412               logs = tmp_logs  # No error, now safe to assign to logs.
#    1413               end_step = step + data_handler.step_increment
# -> 1414               callbacks.on_train_batch_end(end_step, logs)
#    1415               if self.stop_training:
#    1416                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1105       # Only block async when verbose = 1.
#    1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
# -> 1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#    1109   def _finalize_progbar(self, logs, counter):
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py in update(self, current, values, finalize)
#     974
#     975       message += info
# --> 976       io_utils.print_msg(message, line_break=False)
#     977       message = ''
#     978
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/io_utils.py in print_msg(message, line_break)
#      76     else:
#      77       sys.stdout.write(message)
# ---> 78     sys.stdout.flush()
#      79   else:
#      80     logging.info(message)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in flush(self)
#     342         if self.pub_thread and self.pub_thread.thread is not None and self.pub_thread.thread.is_alive():
#     343             # request flush on the background thread
# --> 344             self.pub_thread.schedule(self._flush)
#     345             # wait for flush to actually get through, if we can.
#     346             # waiting across threads during import can cause deadlocks
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Part 4 - Making the predictions and evaluating the model

# %% [markdown]
# ### Predicting the result of a single observation

# %% [markdown]
# **Homework**
#
# Use our ANN model to predict if the customer with the following informations will leave the bank:
#
# Geography: France
#
# Credit Score: 600
#
# Gender: Male
#
# Age: 40 years old
#
# Tenure: 3 years
#
# Balance: \$ 60000
#
# Number of Products: 2
#
# Does this customer have a credit card? Yes
#
# Is this customer an Active Member: Yes
#
# Estimated Salary: \$ 50000
#
# So, should we say goodbye to that customer?

# %% [markdown]
# **Solution**

# %%
print(ann.predict(sc.transform([[1, 0, 0, 600, 1, 40, 3, 60000, 2, 1, 1, 50000]])) > 0.5)

# %% [markdown]
# Therefore, our ANN model predicts that this customer stays in the bank!
#
# **Important note 1:** Notice that the values of the features were all input in a double pair of square brackets. That's because the "predict" method always expects a 2D array as the format of its inputs. And putting our values into a double pair of square brackets makes the input exactly a 2D array.
#
# **Important note 2:** Notice also that the "France" country was not input as a string in the last column but as "1, 0, 0" in the first three columns. That's because of course the predict method expects the one-hot-encoded values of the state, and as we see in the first row of the matrix of features X, "France" was encoded as "1, 0, 0". And be careful to include these values in the first three columns, because the dummy variables are always created in the first columns.

# %% [markdown]
# ### Predicting the Test set results

# %%
y_pred = ann.predict(X_test)
y_pred = (y_pred > 0.5)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %% [markdown]
# ### Making the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
